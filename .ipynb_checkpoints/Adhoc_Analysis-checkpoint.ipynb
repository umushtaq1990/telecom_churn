# %% [markdown]
# ## Telecom Churn Prediction
# - EDA, Data Cleaning, Visualisations
# - Feature Engineering
# - ML Model Training
# - Hyperparameter Training

# %%
from utilties import *

# %%
sns.set()
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
import warnings
warnings.filterwarnings("ignore")

pd.set_option("display.max_columns",None)
pd.set_option("display.max_rows",None)
pd.set_option('display.width', None)

# %%
import session_info
session_info.show()
# Out:
# <details>
# <summary>Click to view session information</summary>
# <pre>
# -----
# ipywidgets          7.6.5
# matplotlib          3.5.1
# numpy               1.21.5
# pandas              1.4.2
# scipy               1.7.3
# seaborn             0.11.2
# session_info        1.0.0
# sklearn             1.0.2
# utilties            NA
# -----
# </pre>
# <details>
# <summary>Click to view modules imported as dependencies</summary>
# <pre>
# PIL                         9.0.1
# asttokens                   NA
# backcall                    0.2.0
# beta_ufunc                  NA
# binom_ufunc                 NA
# bottleneck                  1.3.4
# cffi                        1.15.0
# colorama                    0.4.4
# cycler                      0.10.0
# cython_runtime              NA
# dateutil                    2.8.2
# debugpy                     1.5.1
# decorator                   5.1.1
# defusedxml                  0.7.1
# executing                   0.8.3
# google                      NA
# importlib_metadata          NA
# ipykernel                   6.9.1
# ipython_genutils            0.2.0
# jedi                        0.18.1
# joblib                      1.1.0
# jupyter_server              1.13.5
# kiwisolver                  1.3.2
# matplotlib_inline           NA
# mkl                         2.4.0
# mpl_toolkits                NA
# nbinom_ufunc                NA
# nt                          NA
# ntsecuritycon               NA
# numexpr                     2.8.1
# packaging                   21.3
# parso                       0.8.3
# pickleshare                 0.7.5
# pkg_resources               NA
# prompt_toolkit              3.0.20
# psutil                      5.8.0
# pure_eval                   0.2.2
# pydev_ipython               NA
# pydevconsole                NA
# pydevd                      2.6.0
# pydevd_concurrency_analyser NA
# pydevd_file_utils           NA
# pydevd_plugins              NA
# pydevd_tracing              NA
# pygments                    2.11.2
# pyparsing                   3.0.4
# pythoncom                   NA
# pytz                        2021.3
# pywintypes                  NA
# setuptools                  61.2.0
# six                         1.16.0
# sphinxcontrib               NA
# stack_data                  0.2.0
# statsmodels                 0.13.2
# threadpoolctl               2.2.0
# tornado                     6.1
# traitlets                   5.1.1
# typing_extensions           NA
# wcwidth                     0.2.5
# win32api                    NA
# win32com                    NA
# win32security               NA
# zipp                        NA
# zmq                         22.3.0
# zope                        NA
# </pre>
# </details> <!-- seems like this ends pre, so might as well be explicit -->
# <pre>
# -----
# IPython             8.2.0
# jupyter_client      6.1.12
# jupyter_core        4.9.2
# jupyterlab          3.3.2
# notebook            6.4.8
# -----
# Python 3.9.12 (main, Apr  4 2022, 05:22:27) [MSC v.1916 64 bit (AMD64)]
# Windows-10-10.0.18362-SP0
# -----
# Session information updated at 2022-07-26 00:29
# </pre>
# </details>

# %% [markdown]
# ## Get Data

# %%
df = pd.read_excel('data/Data_Science_Task.xlsx', sheet_name='Churn Dataset')
df.shape
# Out:
# (3333, 25)

# %%
X = df.drop(columns='churn')
y = df.loc[:, 'churn']
X_data, X_val, y_data, y_val = train_test_split(X, y, test_size=0.1,random_state=40, shuffle=True)   # seperate val data set
df_val = X_val
df_val['churn']=y_val
df_data = X_data
df_data['churn'] = y_data
df_val.to_pickle('data/df_validation.pkl')
df_data.to_pickle('data/df_data.pkl')

# %%
df_val
# Out:
#       customerID  gender  SeniorCitizen US State  Duration  Phone Code  \
# 1994  8022-BECSI    Male              0       MD        84         510
# 3078  5277-ZLOOR  Female              1       AL       107         408
# 1551  6518-KZXCB    Male              0       MI       225         415
# 52    6575-SUVOI  Female              1       VA        10         408
# 307   4115-BNPJY    Male              0       IN       122         408
# 401   9442-JTWDL  Female              0       ID        74         415
# 644   8404-VLQFB  Female              0       CO       111         510
# 800   5671-RQRLP  Female              1       MN        96         415
# 2315  2577-GVSIL    Male              0       MT        42         415
# 1923  7696-CFTAT    Male              0       HI       134         408
# 2720  3426-NIYYL    Male              0       MI       158         415
# 3096  3911-RSNHI  Female              0       CO       118         415
# 2339  4094-NSEDU  Female              1       WV        84         408
# 1451  6890-PFRQX    Male              0       IN       101         415
# 3026  6127-ISGTU  Female              0       NE        78         510
# 537   5844-QVTAT  Female              0       UT       190         415
# 1135  1779-PWPMG  Female              1       ID       144         415
# 398   2519-ERQOJ    Male              1       IL        84         510
# 2372  0730-BGQGF    Male              0       OH       114         415
# 2982  5266-PFRQK    Male              0       OH        87         510
# 2215  4312-GVYNH  Female              0       MS        13         415
# 304   2240-HSJQD    Male              0       AZ       136         510
# 559   3716-UVSPD    Male              0       CO       125         415
# 3081  6376-GAHQE    Male              0       NY       204         415
# 2820  3251-YMVWZ    Male              0       IL        74         510
# 623   5148-HKFIR  Female              0       LA       172         415
# 2859  6963-EZQEE    Male              1       WV        87         415
# 2901  7765-LWVVH  Female              0       MT        85         408
# 2481  6614-YWYSC    Male              1       VA        80         415
# 2329  2972-YDYUW  Female              0       AL       137         415
# 2769  5577-OTWWW  Female              0       WI       137         510
# 2378  2884-GBPFB  Female              0       OR       112         510
# 2933  5220-AGAAX    Male              0       IL        98         510
# 487   3649-JPUGY    Male              0       IN        76         415
#
#      Telephone Number Product: International Product: Voice mail  vmail  \
# 1994         369-2899                     no                  no      0
# 3078         332-3804                     no                  no      0
# 1551         371-2500                     no                  no      0
# 52           349-4396                     no                  no      0
# 307          336-3819                     no                  no      0
# 401          365-9696                     no                  no      0
# 1057         332-2258                     no                 yes     38
# 2532         397-2870                     no                  no      0
# 2992         418-3096                     no                 yes     24
# 3240         392-5716                     no                  no      0
# 1568         397-7500                     no                 yes     27
# 3241         384-6132                    yes                  no      0
# 1460         361-8288                     no                  no      0
# 133          400-3446                     no                  no      0
# 2287         340-5678                     no                  no      0
# 823          346-6941                     no                 yes     24
# 1377         364-9240                     no                 yes     34
# 192          375-3586                     no                  no      0
# 300          330-1835                     no                  no      0
# 603          346-5707                     no                  no      0
# 3289         364-8731                     no                  no      0
# 2392         400-8069                     no                  no      0
# 2752         365-6756                     no                 yes     39
# 612          339-1405                     no                  no      0
# 3126         339-4068                     no                  no      0
# 2537         396-8662                     no                  no      0
# 1024         383-6544                    yes                  no      0
# 2286         372-8925                     no                 yes     42
# 1623         387-6031                     no                  no      0
# 2816         358-3692                     no                  no      0
# 1595         395-6030                     no                  no      0
# 1401         417-5813                     no                  no      0
# 396          339-7139                     no                  no      0
# 225          388-9568                     no                  no      0
# 645          360-2107                     no                 yes     22
# 3152         397-7453                     no                  no      0
# 551          421-1189                     no                  no      0
# 137          379-5592                     no                  no      0
# 2728         369-6308                     no                  no      0
# 2685         407-6391                     no                  no      0
# 1290         355-9324                     no                  no      0
# 2336         403-9468                     no                 yes     37
# 1223         341-4570                     no                 yes     31
# 739          350-2832                     no                  no      0
# 3183         417-9278                     no                  no      0
# 1711         339-7485                    yes                 yes     17
# 1734         351-2773                     no                  no      0
# 1329         370-4395                     no                  no      0
# 1896         400-4020                     no                  no      0
# 2452         351-7807                     no                  no      0
# 793          335-9501                     no                  no      0
# 2936         358-7165                     no                  no      0
# 2203         365-7774                    yes                  no      0
# 2556         422-2571                     no                  no      0
# 1070         379-7779                     no                  no      0
# 98           355-6291                     no                  no      0
# 2909         402-9173                     no                  no      0
# 1602         400-3343                    yes                 yes     44
# 3038         339-2792                     no                 yes     28
# 2409         384-8890                     no                 yes      8
# 2187         416-5660                     no                  no      0
# 2606         332-5820                     no                  no      0
# 2007         381-2726                     no                  no      0
# 2300         389-6955                     no                  no      0
# 1625         369-3756                     no                 yes     38
# 191          359-5461                     no                  no      0
# 3109         365-9371                    yes                  no      0
# 904          370-2688                     no                  no      0
# 3090         407-3949                     no                  no      0
# 3274         336-4960                     no                  no      0
# 1640         397-1659                     no                  no      0
# 2010         332-6958                     no                  no      0
# 1386         334-4678                     no                 yes     35
# 1434         350-9720                     no                 yes     37
# 158          350-9994                     no                  no      0
# 1612         362-9411                     no                  no      0
# 263          377-8608                     no                  no      0
# 2            358-1921                     no                  no      0
# 1702         333-5101                     no                  no      0
# 1886         360-8919                     no                  no      0
# 447          382-5478                     no                  no      0
# 2754         383-4641                     no                 yes     23
# 2034         387-4504                     no                  no      0
# 608          392-6856                     no                  no      0
# 2261         378-9478                     no                  no      0
# 1066         385-3263                     no                 yes     25
# 3262         343-6643                     no                  no      0
# 634          383-5474                     no                  no      0
# 2729         357-7385                     no                  no      0
# 1833         382-6827                     no                  no      0
# 1138         357-1085                     no                  no      0
# 2104         366-2622                     no                  no      0
# 692          343-2741                     no                  no      0
# 789          368-9860                     no                  no      0
# 970          334-6605                     no                  no      0
# 1558         391-8124                     no                 yes     34
# 2441         401-6671                     no                 yes     13
# 485          401-5485                     no                 yes     16
# 684          396-2335                     no                  no      0
# 1639         376-1000                     no                  no      0
# 2568         329-9689                    yes                  no      0
# 2738         352-5393                     no                  no      0
# 1590         367-9765                     no                 yes     39
# 1025         378-2940                     no                 yes     11
# 2552         353-8970                     no                  no      0
# 141          374-3534                     no                 yes     39
# 757          358-5953                     no                  no      0
# 2156         373-2091                     no                  no      0
# 1095         383-2566                     no                  no      0
# 3263         330-4364                     no                  no      0
# 2500         337-2348                     no                 yes     41
# 302          329-7347                     no                  no      0
# 1211         408-9463                     no                  no      0
# 2314         387-5411                     no                 yes     35
# 2114         416-6594                     no                  no      0
# 2539         384-7236                    yes                 yes     28
# 1710         358-3604                     no                  no      0
# 1707         348-7193                     no                  no      0
# 1694         380-8727                     no                  no      0
# 3308         399-5763                     no                  no      0
# 2594         348-1163                    yes                  no      0
# 1873         395-8330                     no                 yes     25
# 1396         412-1076                    yes                 yes     27
# 1158         330-8351                    yes                  no      0
# 1786         409-5519                     no                  no      0
# 1077         344-7197                     no                  no      0
# 678          383-8878                     no                  no      0
# 850          354-9492                     no                  no      0
# 2660         347-8659                     no                  no      0
# 234          359-6196                    yes                  no      0
# 2699         352-6732                     no                  no      0
# 185          333-3221                     no                  no      0
# 283          370-8463                     no                 yes     28
# 2839         363-8033                     no                  no      0
# 371          385-5722                     no                  no      0
# 2030         363-8424                     no                 yes     37
# 1835         333-9511                     no                 yes     37
# 992          375-8934                     no                 yes     26
# 1608         346-3445                     no                 yes     25
# 1457         418-6752                     no                  no      0
# 466          334-9505                     no                 yes     36
# 452          327-3850                     no                  no      0
# 1480         408-5916                     no                  no      0
# 2913         358-4036                     no                  no      0
# 2131         327-9289                     no                 yes     31
# 677          375-3003                     no                  no      0
# 1957         396-2945                     no                  no      0
# 3024         398-5851                     no                  no      0
# 807          417-1477                     no                 yes     30
# 2631         371-5655                     no                 yes     22
# 2263         370-9563                     no                 yes     26
# 3033         414-2663                     no                  no      0
# 2597         369-5810                     no                  no      0
# 2066         338-1815                     no                 yes     26
# 3191         402-3908                     no                  no      0
# 84           395-3026                     no                  no      0
# 1352         359-2915                     no                 yes     16
# 842          366-9538                    yes                  no      0
# 2393         346-5349                     no                 yes     25
# 290          393-6733                     no                 yes     34
# 1236         339-6968                     no                  no      0
# 1586         414-9119                     no                  no      0
# 1937         364-2166                     no                 yes     33
# 1830         351-9037                     no                  no      0
# 15           351-7269                     no                  no      0
# 2217         415-3689                     no                 yes     22
# 431          382-2879                     no                  no      0
# 260          396-4460                     no                 yes     25
# 1988         385-9657                     no                  no      0
# 2763         338-7527                     no                 yes     19
# 80           354-4577                     no                  no      0
# 2275         376-4540                    yes                  no      0
# 2023         386-8118                     no                  no      0
# 3008         401-6977                     no                 yes     31
# 2509         376-4665                     no                  no      0
# 2426         405-9864                     no                  no      0
# 2076         400-8538                    yes                  no      0
# 1740         386-1631                     no                 yes     31
# 361          351-2587                     no                  no      0
# 1965         399-7268                     no                  no      0
# 593          381-9049                     no                 yes     29
# 2473         329-6192                     no                 yes     40
# 2022         352-5542                     no                  no      0
# 1370         359-1441                     no                  no      0
# 1309         389-2540                    yes                  no      0
# 1004         402-3599                     no                 yes     27
# 1097         344-4691                     no                 yes     29
# 3271         368-9073                     no                  no      0
# 1334         379-8681                     no                  no      0
# 914          355-2464                     no                  no      0
# 2248         354-7077                     no                 yes     20
# 2604         409-2412                     no                  no      0
# 1678         349-2157                     no                  no      0
# 355          371-7917                     no                  no      0
# 655          416-8701                     no                  no      0
# 1212         340-7062                     no                  no      0
# 3181         420-3857                     no                  no      0
# 659          368-2845                     no                  no      0
# 788          335-9786                     no                  no      0
# 827          343-6314                     no                  no      0
# 2721         342-1960                     no                  no      0
# 588          345-1524                     no                  no      0
# 1539         353-6038                    yes                  no      0
# 2177         363-4967                     no                  no      0
# 2899         337-7879                     no                 yes     36
# 2600         407-7464                     no                  no      0
# 1060         362-1490                     no                  no      0
# 1960         413-9055                     no                  no      0
# 1405         366-5829                     no                  no      0
# 1938         414-4741                     no                 yes     30
# 1182         346-5068                     no                  no      0
# 215          337-9345                     no                  no      0
# 503          402-9691                    yes                 yes     26
# 857          333-3531                     no                  no      0
# 1197         354-3237                     no                  no      0
# 2919         355-9356                     no                  no      0
# 3140         382-2026                     no                  no      0
# 2018         410-5963                     no                 yes     22
# 2928         391-2231                     no                  no      0
# 1041         381-9234                     no                 yes     38
# 1232         369-5449                     no                  no      0
# 1305         382-4024                     no                  no      0
# 34           395-2854                     no                 yes     25
# 3018         403-4442                     no                  no      0
# 164          335-4584                     no                  no      0
# 1954         373-8483                     no                  no      0
# 1802         379-7009                     no                 yes     36
# 3307         398-3632                     no                  no      0
# 1712         368-3078                     no                  no      0
# 715          420-9971                    yes                  no      0
# 3290         388-4331                     no                  no      0
# 1505         338-1840                     no                  no      0
# 1416         398-7414                     no                  no      0
# 3114         390-1760                     no                  no      0
# 1104         343-4806                     no                  no      0
# 1900         359-7648                     no                  no      0
# 2280         420-8953                     no                 yes     25
# 266          411-9554                     no                 yes     28
# 2778         396-6390                     no                  no      0
# 1299         394-4520                     no                  no      0
# 336          397-4304                     no                  no      0
# 3328         347-6812                     no                 yes     36
# 3196         337-3868                     no                  no      0
# 2602         397-3746                    yes                  no      0
# 831          376-4856                     no                  no      0
# 2327         356-5475                     no                  no      0
# 2025         382-4952                     no                  no      0
# 2787         358-5721                     no                  no      0
# 2679         405-6559                     no                  no      0
# 837          341-2603                    yes                 yes     33
# 656          397-6109                     no                  no      0
# 2230         361-9839                    yes                  no      0
# 1052         378-6772                    yes                  no      0
# 2082         382-9138                     no                 yes     23
# 3002         345-3947                     no                  no      0
# 1650         332-8103                     no                 yes     31
# 785          390-5686                     no                  no      0
# 2878         353-2557                     no                 yes     19
# 727          405-6943                     no                  no      0
# 294          343-2605                     no                 yes     18
# 942          403-3229                     no                  no      0
# 314          359-5890                     no                  no      0
# 592          411-8140                     no                  no      0
# 1421         360-7404                     no                 yes     20
# 646          405-9384                     no                 yes     28
# 435          387-9301                     no                 yes     29
# 3291         335-7324                    yes                 yes     22
# 2037         399-6852                     no                  no      0
# 599          370-3021                     no                 yes     46
# 1533         400-2181                    yes                  no      0
# 1193         352-5118                    yes                 yes     15
# 2312         332-5964                     no                  no      0
# 628          328-2236                     no                  no      0
# 2541         369-7295                     no                  no      0
# 1438         353-9339                     no                  no      0
# 2504         347-6164                     no                  no      0
# 1662         395-7923                    yes                  no      0
# 1609         368-9507                     no                  no      0
# 1579         404-1002                     no                 yes     38
# 1478         379-8526                     no                  no      0
# 3077         395-6913                     no                 yes     29
# 213          405-1842                     no                 yes     31
# 1257         394-9934                     no                  no      0
# 3015         343-5372                     no                 yes     25
# 3238         378-1884                     no                  no      0
# 803          371-8598                     no                  no      0
# 1884         352-9130                    yes                 yes     12
# 3146         406-7670                     no                  no      0
# 1904         352-6068                     no                 yes     33
# 2842         336-1353                     no                 yes     20
# 531          408-4174                     no                  no      0
# 1159         347-7773                     no                  no      0
# 3321         400-2738                     no                  no      0
# 740          414-9027                     no                 yes     20
# 3071         389-8163                     no                 yes     34
# 1351         388-9653                     no                  no      0
# 157          328-6289                     no                 yes     23
# 2435         404-9504                     no                 yes     23
# 916          373-2339                     no                  no      0
# 1554         399-9239                     no                  no      0
# 2480         350-2250                    yes                  no      0
# 1216         411-6294                     no                  no      0
# 746          390-8876                     no                  no      0
# 1485         401-5586                     no                  no      0
# 1953         357-3187                     no                  no      0
# 2086         348-3581                     no                  no      0
# 644          377-1479                     no                 yes     24
# 800          330-2881                     no                 yes     27
# ...
# 2604                    4              4.29              3               No
# 1678                    8              2.40              1              Yes
# 355                     2              3.43              1              Yes
# 655                    10              2.54              5              Yes
# 1212                    8              3.40              1              Yes
# 3181                    4              2.73              5              Yes
# 659                     2              2.24              1               No
# 788                     2              3.19              2               No
# 827                     4              3.29              0               No
# 2721                    6              2.59              1              Yes
# 588                    11              3.65              5              Yes
# 1539                    5              2.89              0               No
# 2177                    1              3.54              2              Yes
# 2899                    4              1.03              1               No
# 2600                    4              3.02              1               No
# 1060                    3              4.13              1              Yes
# 1960                   11              3.75              0               No
# 1405                    7              2.38              4               No
# 1938                    6              1.84              1               No
# 1182                    2              3.89              3              Yes
# 215                     6              3.11              3              Yes
# 503                     3              2.51              0              Yes
# 857                     4              2.48              1               No
# 1197                    3              3.21              4              Yes
# 2919                    5              2.54              0               No
# 3140                    6              4.10              5               No
# 2018                   11              2.03              1              Yes
# 2928                    3              2.65              2               No
# 1041                    6              4.35              0              Yes
# 1232                    6              4.13              0               No
# 1305                    2              2.92              2              Yes
# 34                      4              2.24              0               No
# 3018                    2              3.29              2               No
# 164                     3              1.65              1               No
# 1954                   10              3.19              0              Yes
# 1802                    7              3.73              5               No
# 3307                    4              4.81              4               No
# 1712                    5              2.78              4              Yes
# 715                     6              4.13              1              Yes
# 3290                    0              0.00              0               No
# 1505                    5              2.38              1              Yes
# 1416                    3              2.05              3              Yes
# 3114                    1              3.27              0               No
# 1104                    5              2.81              4              Yes
# 1900                    1              2.67              1               No
# 2280                    6              3.62              2              Yes
# 266                     9              2.27              4               No
# 2778                    3              2.78              1              Yes
# 1299                    2              3.78              2              Yes
# 336                     2              2.86              0              Yes
# 3328                    6              2.67              2              Yes
# 3196                    3              3.29              1               No
# 2602                    2              3.08              2              Yes
# 831                     2              3.19              2               No
# 2327                    1              2.54              6              Yes
# 2025                    3              3.62              2              Yes
# 2787                    6              2.92              1               No
# 2679                    3              0.89              1              Yes
# 837                    13              2.19              0               No
# 656                     4              2.51              0              Yes
# 2230                    3              2.11              2               No
# 1052                    9              2.08              1              Yes
# 2082                    4              2.65              0               No
# 3002                    8              2.40              3               No
# 1650                    2              2.59              1               No
# 785                     5              2.89              3              Yes
# 2878                    6              2.59              0              Yes
# 727                     2              2.48              1              Yes
# 294                     3              2.65              1               No
# 942                     2              1.73              0              Yes
# 314                     2              5.10              0              Yes
# 592                     1              2.59              2               No
# 1421                    7              2.81              0              Yes
# 646                     9              4.16              0              Yes
# 435                     3              3.02              1              Yes
# 3291                   20              3.75              1               No
# 2037                    8              1.81              1              Yes
# 599                     6              2.48              0              Yes
# 1533                    5              3.75              2               No
# 1193                    5              2.35              5               No
# 2312                    3              2.48              0               No
# 628                     5              1.76              1               No
# 2541                    2              3.83              2              Yes
# 1438                    6              4.08              2              Yes
# 2504                    1              3.51              1              Yes
# 1662                    5              3.70              5              Yes
# 1609                    4              3.02              0              Yes
# 1579                    4              4.46              2              Yes
# 1478                    7              2.62              2              Yes
# 3077                    2              3.86              0               No
# 213                     6              3.29              1               No
# 1257                    5              4.86              1               No
# 3015                    7              1.92              2              Yes
# 3238                    3              2.38              3               No
# 803                     3              3.40              1              Yes
# 1884                    7              3.32              2               No
# 3146                    5              3.75              1              Yes
# 1904                    4              3.92              4              Yes
# 2842                    2              2.54              0               No
# 531                     3              1.81              2               No
# 1159                    7              1.73              0              Yes
# 3321                    8              3.56              3               No
# 740                     2              2.54              1              Yes
# 3071                   12              1.70              1              Yes
# 1351                    5              3.21              1              Yes
# 157                     2              3.70              0               No
# 2435                    6              2.78              1              Yes
# 916                     5              3.56              2              Yes
# 1554                   10              3.59              1               No
# 2480                    7              2.78              3              Yes
# 1216                    6              1.59              3               No
# 746                     2              1.73              1              Yes
# 1485                    3              4.16              1              Yes
# 1953                    5              3.00              0              Yes
# 2086                    2              3.40              1               No
# 644                     4              3.78              1              Yes
# 800                     2              3.05              1              Yes
# 2315                    4              1.89              2              Yes
# 1923                    6              3.19              1               No
# 2720                    3              2.78              1               No
# 3096                    5              2.65              3              Yes
# 2339                    4              2.40              1              Yes
# 1451                    2              2.57              2               No
# 3026                    4              2.92              6              Yes
# 537                     3              2.30              0              Yes
# 1135                    3              3.29              2              Yes
# 398                     4              2.30              1              Yes
# 2372                    3              2.73              2               No
# 2982                    5              2.40              2              Yes
# 2215                    3              3.11              0              Yes
# 304                    10              2.78              1              Yes
# 559                     6              2.08              2              Yes
# 3081                    3              1.59              6               No
# 2820                    2              3.56              4               No
# 623                     1              1.92              3               No
# 2859                    3              3.11              0              Yes
# 2901                    7              2.51              4              Yes
# 2481                    4              3.05              1               No
# 2329                    2              2.40              1               No
# 2769                    2              2.46              1               No
# 2378                    7              3.40              3              Yes
# 2933                    4              0.57              1              Yes
# 487                     2              2.84              0              Yes
#
#       churn
# 1994  False
# 3078  False
# 1551   True
# 52    False
# 307    True
# 401   False
# 1057  False
# 2532  False
# 2992  False
# 3240  False
# 1568  False
# 3241   True
# 1460  False
# 133   False
# 2287  False
# 823   False
# 1377  False
# 192   False
# 300   False
# 603   False
# 3289  False
# 2392  False
# 2752  False
# 612   False
# 3126  False
# 2537  False
# 1024  False
# 2286  False
# 1623  False
# 2816   True
# 1595  False
# 1401  False
# 396   False
# 225   False
# 645   False
# 3152  False
# 551   False
# 137   False
# 2728  False
# 2685  False
# 1290  False
# 2336  False
# 1223  False
# 739   False
# 3183  False
# 1711  False
# 1734  False
# 1329  False
# 1896  False
# 2452  False
# 793   False
# 2936   True
# 2203   True
# 2556  False
# 1070  False
# 98     True
# 2909  False
# 1602  False
# 3038  False
# 2409  False
# 2187   True
# 2606   True
# 2007  False
# 2300  False
# 1625  False
# 191   False
# 3109  False
# 904    True
# 3090  False
# 3274  False
# 1640  False
# 2010  False
# 1386  False
# 1434  False
# 158   False
# 1612  False
# 263   False
# 2     False
# 1702   True
# 1886  False
# 447   False
# 2339  False
# 1451  False
# 3026  False
# 537   False
# 1135  False
# 398   False
# 2372  False
# 2982  False
# 2215   True
# 304   False
# 559   False
# 3081  False
# 2820  False
# 623   False
# 2859  False
# 2901   True
# 2481  False
# 2329  False
# 2769  False
# 2378  False
# 2933  False
# 487   False

# %% [markdown]
# ## Seperate Validation Data (10 per of OrignalData)

# %%
print(df_val.shape)
print(df_data.shape)
# Out:
# (334, 25)
# (2999, 25)

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2999 entries, 85 to 2267
# Data columns (total 25 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   customerID              2999 non-null   object
#  1   gender                  2999 non-null   object
#  2   SeniorCitizen           2999 non-null   int64
#  3   US State                2999 non-null   object
#  4   Duration                2999 non-null   int64
#  5   Phone Code              2999 non-null   int64
#  6   Telephone Number        2999 non-null   object
#  7   Product: International  2999 non-null   object
#  8   Product: Voice mail     2999 non-null   object
#  9   vmail                   2999 non-null   int64
#  10  Call day minutes        2999 non-null   float64
#  11  total day calls         2999 non-null   int64
#  12  Total, EUR              2999 non-null   float64
#  13  eve minutes             2999 non-null   float64
#  14  eve calls               2999 non-null   int64
#  15  eve EUR                 2999 non-null   float64
#  16  night minutes           2999 non-null   float64
#  17  night calls             2999 non-null   int64
#  18  night EUR               2999 non-null   float64
#  19  international minutes   2999 non-null   float64
#  20  international calls     2999 non-null   int64
#  21  internatonal EUR        2999 non-null   float64
#  22  service calls           2999 non-null   int64
#  23  PaperlessBilling        2999 non-null   object
#  24  churn                   2999 non-null   bool
# dtypes: bool(1), float64(8), int64(9), object(7)
# memory usage: 588.7+ KB

# %% [markdown]
# ## Get Summary of DF

# %%
Get_Summary_DF(df_data)
# Out:
#                    column                                             values  \
# 0              customerID  [4445-ZJNMU, 5168-MSWXT, 6366-ZGQGL, 2080-SRCD...
# 0                  gender                                     [Male, Female]
# 0           SeniorCitizen                                             [0, 1]
# 0                US State  [VT, GA, AL, AK, UT, ME, CT, CO, AZ, KS, AR, N...
# 0                Duration  [128, 75, 49, 48, 195, 35, 90, 85, 116, 82, 34...
# 0              Phone Code                                    [510, 415, 408]
# 0        Telephone Number  [388-6441, 333-7637, 331-6229, 389-7073, 355-3...
# 0  Product: International                                          [no, yes]
# 0     Product: Voice mail                                          [yes, no]
# 0                   vmail  [29, 0, 28, 37, 41, 45, 12, 27, 36, 44, 25, 17...
# 0        Call day minutes  [179.3, 117.3, 214.4, 211.7, 63.2, 149.3, 37.8...
# 0         total day calls  [104, 114, 78, 115, 108, 113, 80, 102, 52, 90,...
# 0              Total, EUR  [30.48, 19.94, 36.45, 35.99, 10.74, 25.38, 6.4...
# 0             eve minutes  [225.9, 201.1, 235.2, 159.9, 220.2, 242.2, 155...
# 0               eve calls  [86, 61, 100, 84, 88, 122, 105, 114, 104, 118,...
# 0                 eve EUR  [19.2, 17.09, 19.99, 13.59, 18.72, 20.59, 13.2...
# 0           night minutes  [323.0, 107.9, 206.2, 144.1, 184.0, 174.3, 175...
# 0             night calls  [78, 82, 107, 80, 99, 104, 111, 133, 106, 83, ...
# 0               night EUR  [14.54, 4.86, 9.28, 6.48, 8.28, 7.84, 7.88, 4....
# 0   international minutes  [8.6, 12.2, 8.0, 5.1, 8.9, 14.2, 10.9, 12.0, 1...
# 0     international calls  [7, 3, 13, 1, 6, 5, 2, 4, 8, 9, 15, 12, 0, 11,...
# 0        internatonal EUR  [2.32, 3.29, 2.16, 1.38, 2.4, 3.83, 2.94, 3.24...
# 0           service calls                     [0, 1, 3, 2, 5, 4, 6, 7, 9, 8]
# 0        PaperlessBilling                                          [Yes, No]
# 0                   churn                                      [False, True]
#
#   values_count_incna values_count_nona num_miss pct_miss
# 0               2999              2999        0      0.0
# 0                  2                 2        0      0.0
# 0                  2                 2        0      0.0
# 0                 51                51        0      0.0
# 0                211               211        0      0.0
# 0                  3                 3        0      0.0
# 0               2977              2977        0      0.0
# 0                  2                 2        0      0.0
# 0                  2                 2        0      0.0
# 0                 46                46        0      0.0
# 0               1590              1590        0      0.0
# 0                117               117        0      0.0
# 0               1590              1590        0      0.0
# 0               1520              1520        0      0.0
# 0                122               122        0      0.0
# 0               1364              1364        0      0.0
# 0               1509              1509        0      0.0
# 0                119               119        0      0.0
# 0                900               900        0      0.0
# 0                159               159        0      0.0
# 0                 20                20        0      0.0
# 0                159               159        0      0.0
# 0                 10                10        0      0.0
# 0                  2                 2        0      0.0
# 0                  2                 2        0      0.0

# %%
cat_feats = ['gender', 'SeniorCitizen', 'Product: International', 'Product: Voice mail','Phone Code',
             'PaperlessBilling','service calls','churn']
num_feats = list(set(df_data.columns)-set(['customerID','Telephone Number', 'US State']+cat_feats))

# %% [markdown]
# ## Numeric & Categorical Feats
# - 'gender',  'SeniorCitizen', 'Product: International', 'Product: Voice mail','Phone Code','PaperlessBilling','service calls', 'churn'
# - 'vmail', 'Total, EUR', 'night calls', 'Duration', 'night minutes', 'internatonal EUR', 'international minutes', 'eve minutes', 'Call day minutes', 'eve calls', 'eve EUR', 'night EUR', 'total day calls', 'international calls'

# %% [markdown]
# ## Other Potential Feats (if possible to get)
#
# - Age, Martial_Status,Dependents,
# - ContractInfo, CreditHistory, PreviousPackages,PaymentMethod,  BillAmount, InternetPackage,
# - CustomerSurvey, OnlineSecurity
# - Past History of Each User(Last X Months feats could be generated .eg: num_calls, calls_time, internet_usage, complains etc)

# %% [markdown]
# ## Check Churn Feature

# %%
fig, (axes) = plt.subplots(2,1, figsize=(12,10))
fig.subplots_adjust(wspace=0.2, hspace=0.6)
Plot_Bar_Mit_Num_Per(df_data, 'churn', axes[0], 'Churn')
fig.delaxes(axes[1])

# %% [markdown]
# ## Numeric Feats Correlation

# %%
sns.heatmap(df[num_feats].corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Directly Dependent Feats**
# - 'Total EUR'  -> 'Call day minutes'
# - 'eve EUR' -> 'eve minutes'
# - 'night EUR' -> 'night_minutes'
# - 'internatonal EUR' -> 'international_minutes'
#
# let's drop them:

# %%
num_feats = list(set(num_feats)-set(['Total, EUR', 'eve EUR', 'night EUR', 'internatonal EUR']))
corr_matrix = df[num_feats].corr()
sns.heatmap(corr_matrix);

# %% [markdown]
# ## Box Plot to See Numeric Feats Distribution wrt Churn Feats

# %%
fig, axes = plt.subplots(nrows=5, ncols=2, figsize=(10,16))
for idx, feat in enumerate(num_feats):
    ax = axes[int(idx / 2), idx % 2]
    sns.boxplot(x='churn', y = feat, data=df_data, ax=ax)
    ax.set_xlabel('')
    ax.set_ylabel(feat)
fig.tight_layout();

# %% [markdown]
# - Call day minutes and vmail shows interesting trend

# %% [markdown]
# ## Distribution trend for individual Numeric Feats

# %%
@interact( feature = list(num_feats))
def Inter_Plot_Num_Churn(feature):
    Numeric_Distribution_Plot(df_data, feature,'churn' )
# Out:
# interactive(children=(Dropdown(description='feature', options=('vmail', 'eve minutes', 'international minutes'…

# %% [markdown]
# ## Categorical Features wrt Churn Feat

# %%
fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(12,8))
for idx, feat in enumerate(cat_feats):
    ax = axes[int(idx / 2), idx % 2]
    sns.countplot(x=feat, hue = 'churn', data=df_data, ax=ax)
    ax.set_xlabel('')
    ax.set_ylabel(feat)

# %%
Per_Stacked_Bar_Plot_Cat_Feats(cat_feats, 'Churn Rate')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
# ----> 1 Per_Stacked_Bar_Plot_Cat_Feats(cat_feats, 'Churn Rate')
#
# NameError: name 'Per_Stacked_Bar_Plot_Cat_Feats' is not defined

# %% [markdown]
# - 'Product International' , 'service calls' column shows interesting result

# %% [markdown]
# ## Distribution trend for individual Categorical Feats

# %%
@interact( feature = cat_feats)
def Inter_Plot_Cat_Churn(feature):
    Plot_Cat_Col(df_data, feature,'churn')

# %% [markdown]
# ## Churn Analysis wrt States

# %%
pd.crosstab(df_data['US State'], df_data['churn'])

# %%
churn_state = df_data.groupby(['US State'])['churn'].agg([np.mean]).sort_values(by='mean', ascending=False)
churn_state.plot.bar(title = "Percentage Churn wrt States", figsize=(16,6))
plt.show()

# %% [markdown]
# ## Facts Churn wrt States
# - churn rate in New Jersey and California are above 25% and less than 6% for Hawaii and Alaska.
# - However small dataset is problem to get better insight

# %% [markdown]
# ## Categorical Feat importance with Mutual_Information Score

# %%
def Compute_Mutual_Info(CAT_SERIES):
    return mutual_info_score(CAT_SERIES, df_data.churn)

categorical_variables = df_data[cat_feats].drop('churn', axis=1)
feature_importance = categorical_variables.apply(Compute_Mutual_Info).sort_values(ascending=False)
print(feature_importance)

# %% [markdown]
# ## Prepare Data
# - Map Categorical Feats
# - Scale numeric Feats

# %%
df_all_data = df_data[num_feats+cat_feats]
df_all_data = Convert_Cat_Feats(df_all_data)
df_all_data = Scale_Num_Feats_Train(df_all_data, num_feats)  # save max, min values in config file for pred use cases
df_all_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [18], in <cell line: 3>()
#       1 df_all_data = df_data[num_feats+cat_feats]
#       2 df_all_data = Convert_Cat_Feats(df_all_data)
# ----> 3 df_all_data = Scale_Num_Feats(df_all_data, num_feats)
#       4 df_all_data
#
# NameError: name 'Scale_Num_Feats' is not defined

# %% [markdown]
# ## Try Following Models to see performance
#
# - 'dummy_classifier'
# - 'k_nearest_neighbors'
# - 'logistic_regression'
# - 'support_vector_machines'
# - 'random_forest'
# - 'gradient_boosting'

# %%
X = df_all_data.drop(columns='churn')
y = df_all_data.loc[:, 'churn']
print(X.columns)
print(y.name)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25,random_state=40, shuffle=True)

# %%
models = create_models()

# %%
# test the accuracy of each model using default hyperparameters
results = []
names = []
scoring = 'accuracy'
for name, model in models:
    model.fit(X_train, y_train).predict(X_test)
    predictions = model.predict(X_test)
    accuracy = accuracy_score(y_test, predictions)
    results.append(accuracy)
    names.append(name)
    print('Classifier: {}, Accuracy: {})'.format(name, accuracy))

# %% [markdown]
# ### RF and Gradient Boosting Model shows interesting results

# %% [markdown]
# ## Default RF Model

# %%
# Running the random forest with default parameters
rfc = RandomForestClassifier(class_weight = 'balanced',random_state=100,n_jobs = -1)
rfc.fit(X_train,y_train)
Get_ROC(rfc, X_test, y_test)

# %% [markdown]
# ## Hyperparameter Tuning for RF Model

# %% [markdown]
# ## Tune individual Parameters of RF Model
# - max_depth
# - n_estimators
# - min_samples_split
# - min_samples_leaf
# - max_features

# %%
Tune_Single_Parameter(X_train, y_train, PAR_NAME= 'max_depth', 
                      PARAMETER={'max_depth': range(2, 25, 1)}, N_FOLD=5, TARGET="precision")
Tune_Single_Parameter(X_train, y_train, PAR_NAME= 'n_estimators', 
                      PARAMETER={'n_estimators': [10,25,50,75,100]}, N_FOLD=5, TARGET="precision")
Tune_Single_Parameter(X_train, y_train, PAR_NAME= 'min_samples_split', 
                      PARAMETER={'min_samples_split': range(10,200,10)}, N_FOLD=5, TARGET="precision")
Tune_Single_Parameter(X_train, y_train, PAR_NAME= 'min_samples_leaf', 
                      PARAMETER={'min_samples_leaf': range(10,200,10)}, N_FOLD=3, TARGET="precision")
Tune_Single_Parameter(X_train, y_train, PAR_NAME= 'max_features', 
                      PARAMETER={'max_features': range(5,16,3)}, N_FOLD=3, TARGET="precision")

# %% [markdown]
# ## Find Best Hyper Parameters for RF Model

# %%
param_grid = {
    'max_depth': [10,13,15,17,20],
    'min_samples_split': [5,10,15], 
    'min_samples_leaf': [5,8,11,14,17] }

rf = RandomForestClassifier(class_weight = 'balanced',random_state=100)
grid_search = GridSearchCV(estimator = rf, param_grid = param_grid, #scoring='precision',
                          cv = 3, n_jobs = -1,verbose = 1,return_train_score=True)

grid_search.fit(X_train, y_train)
print(grid_search.best_score_)
print(grid_search.best_params_)
print('We can get accuracy of',grid_search.best_score_,'using',grid_search.best_params_)

# %% [markdown]
# ## Train RF Model With Best Parameters

# %%
rfc = RandomForestClassifier(bootstrap=True,random_state=100,
                             max_depth=grid_search.best_params_['max_depth'],
                             min_samples_split=grid_search.best_params_['min_samples_split'],
                              class_weight='balanced')
rfc.fit(X_train,y_train)
Get_ROC(rfc, X_test, y_test)

# %% [markdown]
# ## Hyperparameter Tuning Increased
# - Accuray increase
# - AUC increase
# - Recall increase

# %% [markdown]
# ## RF Model Feat Importance

# %%
Get_RF_Model_Feat_Importance(rfc, X_train.columns, 17)

# %% [markdown]
# ## Save Model as Pickle File

# %%
pickle.dump(rfc, open(f'model/RF_V001.pkl', 'wb'))

# %%
from get_pred import Main_Pred

# %%
Main_Pred('8022-BECSI')

# %%
df_validation_ = df_val[num_feats + cat_feats]
df_validation_ = Convert_Cat_Feats(df_validation_)
df_validation_ = Scale_Num_Feats(df_validation_, num_feats)
df_validation_

# %%
num_feats + cat_feats
